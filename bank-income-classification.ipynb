# %%
# libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
df = pd.read_csv("D:\\income_evaluation.csv")

# %%
df.head(40)
# Out:
#     age          workclass   fnlwgt      education   education-num  \
# 0    39          State-gov    77516      Bachelors              13
# 1    50   Self-emp-not-inc    83311      Bachelors              13
# 2    38            Private   215646        HS-grad               9
# 3    53            Private   234721           11th               7
# 4    28            Private   338409      Bachelors              13
# 5    37            Private   284582        Masters              14
# 6    49            Private   160187            9th               5
# 7    52   Self-emp-not-inc   209642        HS-grad               9
# 8    31            Private    45781        Masters              14
# 9    42            Private   159449      Bachelors              13
# 10   37            Private   280464   Some-college              10
# 11   30          State-gov   141297      Bachelors              13
# 12   23            Private   122272      Bachelors              13
# ...

# %%
# in some cells there is ? mark, we have to replace them with NaN
df = pd.read_csv('D:\\income_evaluation.csv', na_values=['?',' ?','? '])

# %%
df.head(40)
# Out:
#     age          workclass   fnlwgt      education   education-num  \
# 0    39          State-gov    77516      Bachelors              13
# 1    50   Self-emp-not-inc    83311      Bachelors              13
# 2    38            Private   215646        HS-grad               9
# 3    53            Private   234721           11th               7
# 4    28            Private   338409      Bachelors              13
# 5    37            Private   284582        Masters              14
# 6    49            Private   160187            9th               5
# 7    52   Self-emp-not-inc   209642        HS-grad               9
# 8    31            Private    45781        Masters              14
# 9    42            Private   159449      Bachelors              13
# 10   37            Private   280464   Some-college              10
# 11   30          State-gov   141297      Bachelors              13
# 12   23            Private   122272      Bachelors              13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
# age                32561 non-null int64
#  workclass         30725 non-null object
#  fnlwgt            32561 non-null int64
#  education         32561 non-null object
#  education-num     32561 non-null int64
#  marital-status    32561 non-null object
#  occupation        30718 non-null object
#  relationship      32561 non-null object
#  race              32561 non-null object
#  sex               32561 non-null object
#  capital-gain      32561 non-null int64
#  capital-loss      32561 non-null int64
#  hours-per-week    32561 non-null int64
#  native-country    31978 non-null object
#  income            32561 non-null object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.isnull().sum()
# Out:
# age                   0
#  workclass         1836
#  fnlwgt               0
#  education            0
#  education-num        0
#  marital-status       0
#  occupation        1843
#  relationship         0
#  race                 0
#  sex                  0
#  capital-gain         0
#  capital-loss         0
#  hours-per-week       0
#  native-country     583
#  income               0
# dtype: int64

# %%
df.describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
df.median()
# Out:
# age                    37.0
#  fnlwgt            178356.0
#  education-num         10.0
#  capital-gain           0.0
#  capital-loss           0.0
#  hours-per-week        40.0
# dtype: float64

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %%
df[' native-country'].isnull().sum()
# Out:
# 583

# %%
df[' workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name:  workclass, dtype: int64

# %%
df[' workclass'].fillna(' Private', inplace=True)

# %%
df[' workclass'].isnull().sum()
# Out:
# 0

# %%
df[' workclass'].value_counts()
# Out:
#  Private             24532
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name:  workclass, dtype: int64

# %%
df['age'].describe()
# Out:
# count    32561.000000
# mean        38.581647
# std         13.640433
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
sns.distplot(df['age'], kde=True, bins=30, color='blue')

# %%
df.isnull().sum()
# Out:
# age                   0
#  workclass            0
#  fnlwgt               0
#  education            0
#  education-num        0
#  marital-status       0
#  occupation        1843
#  relationship         0
#  race                 0
#  sex                  0
#  capital-gain         0
#  capital-loss         0
#  hours-per-week       0
#  native-country     583
#  income               0
# dtype: int64

# %%
df[' occupation'].value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name:  occupation, dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64

# %%
df.shape
# Out:
# (30162, 15)

# %%
df[" native-country"].value_counts(normalize = True)
# Out:
#  United-States                 0.911876
#  Mexico                        0.020224
#  Philippines                   0.006233
#  Germany                       0.004244
#  Puerto-Rico                   0.003614
#  Canada                        0.003548
#  India                         0.003315
#  El-Salvador                   0.003315
#  Cuba                          0.003050
#  England                       0.002851
#  Jamaica                       0.002652
#  South                         0.002354
#  Italy                         0.002254
#  China                         0.002254
#  Dominican-Republic            0.002221
#  Vietnam                       0.002122
#  Guatemala                     0.002089
#  Japan                         0.001956
#  Poland                        0.001857
#  Columbia                      0.001857
#  Haiti                         0.001392
#  Iran                          0.001392
#  Taiwan                        0.001392
# ...

# %%
# we see that 91% of people are form USA
# so, we can remove others
df = df[df[' native-country'] == ' United-States']

# %%
cat_cols = df.select_dtypes("object").columns
cat_cols
# Out:
# Index([' workclass', ' education', ' marital-status', ' occupation',
#        ' relationship', ' race', ' sex', ' native-country', ' income'],
#       dtype='object')

# %%
sns.set_style('darkgrid')
for i, col in enumerate(cat_cols):
    plt.figure(num = i, figsize = (8,8))
    chart = sns.countplot(x= col, data = df, order = df[col].value_counts().index, hue = " income")
    plt.tight_layout()
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27504 entries, 0 to 32560
# Data columns (total 15 columns):
# age                27504 non-null int64
#  workclass         27504 non-null object
#  fnlwgt            27504 non-null int64
#  education         27504 non-null object
#  education-num     27504 non-null int64
#  marital-status    27504 non-null object
#  occupation        27504 non-null object
#  relationship      27504 non-null object
#  race              27504 non-null object
#  sex               27504 non-null object
#  capital-gain      27504 non-null int64
#  capital-loss      27504 non-null int64
#  hours-per-week    27504 non-null int64
#  native-country    27504 non-null object
#  income            27504 non-null object
# dtypes: int64(6), object(9)
# memory usage: 4.6+ MB

# %%
num_vars = df.select_dtypes(['int64','float64']).columns

# %%
num_vars
# Out:
# Index(['age', ' fnlwgt', ' education-num', ' capital-gain', ' capital-loss',
#        ' hours-per-week'],
#       dtype='object')

# %%
corr = df[num_vars].corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask = mask, vmax= .3, annot = True, square=True, cmap="YlGnBu")

# %%
df[num_vars].describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  27504.000000  2.750400e+04    27504.000000   27504.000000
# mean      38.504290  1.870550e+05       10.222150    1120.499782
# std       13.184357  1.047236e+05        2.378829    7509.268774
# min       17.000000  1.376900e+04        1.000000       0.000000
# 25%       28.000000  1.158562e+05        9.000000       0.000000
# 50%       37.000000  1.768105e+05       10.000000       0.000000
# 75%       47.000000  2.341080e+05       13.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   27504.000000     27504.000000
# mean       90.272724        40.970986
# std       408.469723        12.041120
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
df[df[' capital-gain'] == 0].count()[0] / df.shape[0]
# Out:
# 0.9142306573589296

# %%
df[df[' capital-loss'] == 0].count()[0] / df.shape[0]
# Out:
# 0.9516797556719022

# %%
df[' capital-gain'].describe()
# Out:
# count    27504.000000
# mean      1120.499782
# std       7509.268774
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max      99999.000000
# Name:  capital-gain, dtype: float64

# %%
df[df[' capital-gain'] < 30000][' capital-gain']
# Out:
# 0         2174
# 1            0
# 2            0
# 3            0
# 5            0
#          ...
# 32556        0
# 32557        0
# 32558        0
# 32559        0
# 32560    15024
# Name:  capital-gain, Length: 27361, dtype: int64

# %%
df = df[df[" capital-gain"] < 30000]

# %%
df.shape
# Out:
# (27361, 15)

# %%
df = df.drop(" capital-loss", axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27361 entries, 0 to 32560
# Data columns (total 14 columns):
# age                27361 non-null int64
#  workclass         27361 non-null object
#  fnlwgt            27361 non-null int64
#  education         27361 non-null object
#  education-num     27361 non-null int64
#  marital-status    27361 non-null object
#  occupation        27361 non-null object
#  relationship      27361 non-null object
#  race              27361 non-null object
#  sex               27361 non-null object
#  capital-gain      27361 non-null int64
#  hours-per-week    27361 non-null int64
#  native-country    27361 non-null object
#  income            27361 non-null object
# dtypes: int64(5), object(9)
# memory usage: 3.1+ MB

# %%
df.select_dtypes("object").columns
# Out:
# Index([' workclass', ' education', ' marital-status', ' occupation',
#        ' relationship', ' race', ' sex', ' native-country', ' income'],
#       dtype='object')

# %%
categorical_columns = df.select_dtypes("object").columns
categorical_columns
# Out:
# Index([' workclass', ' education', ' marital-status', ' occupation',
#        ' relationship', ' race', ' sex', ' native-country', ' income'],
#       dtype='object')

# %%
make_dummy = [' workclass', ' marital-status', ' occupation',
       ' relationship', ' race', ' sex', ' native-country']

# %%
df.columns
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' hours-per-week', ' native-country', ' income'],
#       dtype='object')

# %%
df[[' education',' education-num']]
# it's better to use education-num col
# Out:
#          education   education-num
# 0        Bachelors              13
# 1        Bachelors              13
# 2          HS-grad               9
# 3             11th               7
# 5          Masters              14
# ...            ...             ...
# 32556   Assoc-acdm              12
# 32557      HS-grad               9
# 32558      HS-grad               9
# 32559      HS-grad               9
# 32560      HS-grad               9
#
# [27361 rows x 2 columns]

# %%
dummies = pd.get_dummies(df[make_dummy], drop_first= True )

# %%
dummies
# Out:
#         workclass_ Local-gov   workclass_ Private   workclass_ Self-emp-inc  \
# 0                          0                    0                         0
# 1                          0                    0                         0
# 2                          0                    1                         0
# 3                          0                    1                         0
# 5                          0                    1                         0
# ...                      ...                  ...                       ...
# 32556                      0                    1                         0
# 32557                      0                    1                         0
# 32558                      0                    1                         0
# 32559                      0                    1                         0
# 32560                      0                    0                         1
#
# ...

# %%
df = df.drop(make_dummy, axis = 1)
df = pd.concat([df, dummies], axis = 1)

# %%
df.head()
# Out:
#    age   fnlwgt   education   education-num   capital-gain   hours-per-week  \
# 0   39    77516   Bachelors              13           2174               40
# 1   50    83311   Bachelors              13              0               13
# 2   38   215646     HS-grad               9              0               40
# 3   53   234721        11th               7              0               40
# 5   37   284582     Masters              14              0               40
#
#    income   workclass_ Local-gov   workclass_ Private  \
# 0   <=50K                      0                    0
# 1   <=50K                      0                    0
# 2   <=50K                      0                    1
# 3   <=50K                      0                    1
# 5   <=50K                      0                    1
#
#     workclass_ Self-emp-inc  ...   relationship_ Not-in-family  \
# 0                         0  ...                             1
# ...

# %%
df.columns
# Out:
# Index(['age', ' fnlwgt', ' education', ' education-num', ' capital-gain',
#        ' hours-per-week', ' income', ' workclass_ Local-gov',
#        ' workclass_ Private', ' workclass_ Self-emp-inc',
#        ' workclass_ Self-emp-not-inc', ' workclass_ State-gov',
#        ' workclass_ Without-pay', ' marital-status_ Married-AF-spouse',
#        ' marital-status_ Married-civ-spouse',
#        ' marital-status_ Married-spouse-absent',
#        ' marital-status_ Never-married', ' marital-status_ Separated',
#        ' marital-status_ Widowed', ' occupation_ Armed-Forces',
#        ' occupation_ Craft-repair', ' occupation_ Exec-managerial',
#        ' occupation_ Farming-fishing', ' occupation_ Handlers-cleaners',
#        ' occupation_ Machine-op-inspct', ' occupation_ Other-service',
#        ' occupation_ Priv-house-serv', ' occupation_ Prof-specialty',
#        ' occupation_ Protective-serv', ' occupation_ Sales',
# ...

# %%
df[' income'].value_counts()
# Out:
#  <=50K    20505
#  >50K      6856
# Name:  income, dtype: int64

# %%
df[' income'] = df[' income'].apply(lambda x: 1 if x==" >50K" else 0)

# %%
df[' income'].describe()
# Out:
# count    27361.000000
# mean         0.250576
# std          0.433352
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name:  income, dtype: float64

# %%
df.isnull().sum()
# Out:
# age                                       0
#  fnlwgt                                   0
#  education                                0
#  education-num                            0
#  capital-gain                             0
#  hours-per-week                           0
#  income                                   0
#  workclass_ Local-gov                     0
#  workclass_ Private                       0
#  workclass_ Self-emp-inc                  0
#  workclass_ Self-emp-not-inc              0
#  workclass_ State-gov                     0
#  workclass_ Without-pay                   0
#  marital-status_ Married-AF-spouse        0
#  marital-status_ Married-civ-spouse       0
#  marital-status_ Married-spouse-absent    0
#  marital-status_ Never-married            0
#  marital-status_ Separated                0
#  marital-status_ Widowed                  0
#  occupation_ Armed-Forces                 0
#  occupation_ Craft-repair                 0
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  27361.000000  2.736100e+04    27361.000000   27361.000000
# mean      38.465626  1.870255e+05       10.208216     613.090530
# std       13.183461  1.047411e+05        2.370142    2564.597727
# min       17.000000  1.376900e+04        1.000000       0.000000
# 25%       28.000000  1.158310e+05        9.000000       0.000000
# 50%       37.000000  1.768110e+05       10.000000       0.000000
# 75%       47.000000  2.341080e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   27828.000000
#
#         hours-per-week        income   workclass_ Local-gov  \
# count     27361.000000  27361.000000           27361.000000
# mean         40.926026      0.250576               0.071306
# std          12.019301      0.433352               0.257340
# min           1.000000      0.000000               0.000000
# 25%          40.000000      0.000000               0.000000
# ...

# %% [markdown]
# ## Modeling

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.dummy import DummyClassifier
import sklearn.metrics as metrics

# %%
df.columns
# Out:
# Index(['age', ' fnlwgt', ' education', ' education-num', ' capital-gain',
#        ' hours-per-week', ' income', ' workclass_ Local-gov',
#        ' workclass_ Private', ' workclass_ Self-emp-inc',
#        ' workclass_ Self-emp-not-inc', ' workclass_ State-gov',
#        ' workclass_ Without-pay', ' marital-status_ Married-AF-spouse',
#        ' marital-status_ Married-civ-spouse',
#        ' marital-status_ Married-spouse-absent',
#        ' marital-status_ Never-married', ' marital-status_ Separated',
#        ' marital-status_ Widowed', ' occupation_ Armed-Forces',
#        ' occupation_ Craft-repair', ' occupation_ Exec-managerial',
#        ' occupation_ Farming-fishing', ' occupation_ Handlers-cleaners',
#        ' occupation_ Machine-op-inspct', ' occupation_ Other-service',
#        ' occupation_ Priv-house-serv', ' occupation_ Prof-specialty',
#        ' occupation_ Protective-serv', ' occupation_ Sales',
# ...

# %%
X = df.drop([" income"," education"], axis = 1)
y = df[" income"]

# %%
def train_show_results(model, split_share = 0.2,  **kwargs):
    
    print(f"Training using {model} with {kwargs}")
    M = model(**kwargs)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = split_share, stratify = y)
    
    M.fit(X_train, y_train)
    preds = M.predict(X_test)
    print(metrics.classification_report(preds, y_test))
    
    ax = metrics.plot_roc_curve(M, X_test, y_test)
    plt.title(f"ROC-AUC curve using {str(model).split('.')[-1]}")
    plt.show()

# %%
train_show_results(DummyClassifier, strategy = "uniform")
# Out:
# Training using <class 'sklearn.dummy.DummyClassifier'> with {'strategy': 'uniform'}
#               precision    recall  f1-score   support
#
#            0       0.49      0.74      0.59      2690
#            1       0.50      0.24      0.33      2783
#
#     accuracy                           0.49      5473
#    macro avg       0.49      0.49      0.46      5473
# weighted avg       0.49      0.49      0.46      5473

# %%
train_show_results(LogisticRegression, C = 1e9)
# Out:
# Training using <class 'sklearn.linear_model._logistic.LogisticRegression'> with {'C': 1000000000.0}
#               precision    recall  f1-score   support
#
#            0       0.98      0.78      0.87      5154
#            1       0.17      0.73      0.28       319
#
#     accuracy                           0.78      5473
#    macro avg       0.57      0.76      0.57      5473
# weighted avg       0.93      0.78      0.83      5473

# %%
train_show_results(LogisticRegression, penalty = "l1", solver = "liblinear")
# Out:
# Training using <class 'sklearn.linear_model._logistic.LogisticRegression'> with {'penalty': 'l1', 'solver': 'liblinear'}
#               precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90      4322
#            1       0.61      0.73      0.66      1151
#
#     accuracy                           0.85      5473
#    macro avg       0.77      0.80      0.78      5473
# weighted avg       0.86      0.85      0.85      5473

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
train_show_results(DecisionTreeClassifier)
# Out:
# Training using <class 'sklearn.tree._classes.DecisionTreeClassifier'> with {}
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      4066
#            1       0.59      0.58      0.59      1407
#
#     accuracy                           0.79      5473
#    macro avg       0.73      0.72      0.72      5473
# weighted avg       0.79      0.79      0.79      5473

# %%
train_show_results(DecisionTreeClassifier, criterion ='entropy')
# Out:
# Training using <class 'sklearn.tree._classes.DecisionTreeClassifier'> with {'criterion': 'entropy'}
#               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.87      4069
#            1       0.62      0.61      0.61      1404
#
#     accuracy                           0.80      5473
#    macro avg       0.74      0.74      0.74      5473
# weighted avg       0.80      0.80      0.80      5473

# %%
train_show_results(DecisionTreeClassifier, max_features='log2')
# Out:
# Training using <class 'sklearn.tree._classes.DecisionTreeClassifier'> with {'max_features': 'log2'}
#               precision    recall  f1-score   support
#
#            0       0.87      0.87      0.87      4083
#            1       0.61      0.60      0.61      1390
#
#     accuracy                           0.80      5473
#    macro avg       0.74      0.74      0.74      5473
# weighted avg       0.80      0.80      0.80      5473

# %%
train_show_results(RandomForestClassifier, max_depth = 150)
# Out:
# Training using <class 'sklearn.ensemble._forest.RandomForestClassifier'> with {'max_depth': 150}
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89      4278
#            1       0.61      0.70      0.65      1195
#
#     accuracy                           0.84      5473
#    macro avg       0.76      0.79      0.77      5473
# weighted avg       0.84      0.84      0.84      5473

# %%
from sklearn.neighbors import KNeighborsClassifier
train_show_results(KNeighborsClassifier, n_neighbors=2)
# Out:
# Training using <class 'sklearn.neighbors._classification.KNeighborsClassifier'> with {'n_neighbors': 2}
#               precision    recall  f1-score   support
#
#            0       0.94      0.79      0.86      4863
#            1       0.27      0.60      0.37       610
#
#     accuracy                           0.77      5473
#    macro avg       0.60      0.69      0.61      5473
# weighted avg       0.86      0.77      0.81      5473
